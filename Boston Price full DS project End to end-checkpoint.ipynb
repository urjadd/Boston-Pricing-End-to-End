# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston

# %%
boston=load_boston()
# Out:
# C:\Users\urjad\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
print(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
boston.keys() #??
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
boston.filename
# Out:
# 'boston_house_prices.csv'

# %%
bos=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
bos.shape
# Out:
# (506, 13)

# %%
#bos.target=boston.target  # this doesn't work
bos['target']=boston.target

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
bos.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
bos.shape
# Out:
# (506, 14)

# %%
bos.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# target     float64
# dtype: object

# %%
bos.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
sns.heatmap(bos.isnull())
# Out:
# <AxesSubplot:>

# %%
bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bos.CRIM.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
bos.ZN.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
bos.plot(kind='box',subplots=True,layout=(2,7))
# Out:
# CRIM          AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# ZN         AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# INDUS      AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# CHAS       AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# NOX        AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# RM         AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# AGE        AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# DIS              AxesSubplot(0.125,0.125;0.0945122x0.343182)
# RAD           AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# TAX           AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# PTRATIO       AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# B             AxesSubplot(0.578659,0.125;0.0945122x0.343182)
# LSTAT         AxesSubplot(0.692073,0.125;0.0945122x0.343182)
# target        AxesSubplot(0.805488,0.125;0.0945122x0.343182)
# dtype: object

# %%
bos.CHAS.plot.box()
# Out:
# <AxesSubplot:>

# %%
# Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(bos))
z
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT    target
# ...

# %%
np.where(z>3)
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#         200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#         220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#         277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#         357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#         380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#         416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#         437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64),
#  array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#          1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#          5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#          3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#          0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
# ...

# %%
bos['CRIM'].plot.hist() #skewed data
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 2 methods to remove outliers
#0 = log transform
#.5= sqrt transform

from scipy.stats import boxcox
bos["CRIM"] = boxcox(bos['CRIM'],0)
bos.CRIM.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.scatter(bos['B'],bos['target'])

# %%
plt.scatter(bos['CRIM'],bos['target'])

# %%
plt.scatter(bos['RM'],bos['target'])

# %%
sns.pairplot(bos)

# %%
corr_nmap=bos.corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corr_nmap,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot('LSTAT',"RM",data = bos)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='RM'>

# %%
sns.regplot('LSTAT',"CRIM",data = bos)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='CRIM'>

# %%
# it shoes that lstat has a negative value

plt.scatter(bos.target,bos.LSTAT)

# %%
plt.scatter(bos.target,bos.RM)

# %%
#dropping the lstat col becuase of its negative relationship
#bos.drop('LSTAT',axis=1,inplace=True)
bos.head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0 -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1 -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2 -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3 -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4 -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
bos_new=bos[(z<3).all(axis=1)]
bos_new.shape,bos.shape
# Out:
# ((415, 14), (506, 14))

# %%
bos=bos_new

# %%
bos.shape
# Out:
# (415, 14)

# %%
x=bos.iloc[:,0:-1]
x.head()
y=bos.iloc[:,-1]

# %%
x.head()
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0 -5.064036  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1 -3.600502   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2 -3.601235   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3 -3.430523   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4 -2.672924   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
x.shape,y.shape
# Out:
# ((415, 13), (415,))

# %%
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train, y_test = train_test_split(x,y,test_size=.33)

# %%
x_test.shape
# Out:
# (137, 13)

# %%
x_train.shape
# Out:
# (278, 13)

# %%
x.shape
# Out:
# (415, 13)

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 0.9356262 , -0.46900071,  1.34309655, ..., -1.69960099,
#         -3.84215681,  2.41851824],
#        [-0.6333908 ,  1.0993497 , -0.83997271, ..., -0.83298332,
#         -0.01332068, -0.17803701],
#        [-0.95920574,  0.62884458, -0.73417208, ..., -0.74176041,
#          0.44938144, -1.1082866 ],
#        ...,
#        [-0.86549211,  3.19048359, -1.24082297, ..., -1.65398953,
#         -0.09973006, -1.15683498],
#        [ 0.88616551, -0.46900071,  1.34309655, ..., -1.69960099,
#         -3.91189742,  0.67234266],
#        [-0.31305532, -0.46900071,  0.03623529, ...,  0.35291454,
#          0.07136434, -0.75435326]])

# %%
x_test
# Out:
# array([[ 1.60765803, -0.52781527,  0.97373185, ...,  0.81926349,
#          0.20206538,  1.11805305],
#        [ 0.3929035 , -0.52781527,  1.52152459, ...,  1.3165568 ,
#          0.42047529,  0.9399639 ],
#        [-0.70385623, -0.52781527, -0.19556717, ..., -0.37424044,
#          0.394322  , -0.29458628],
#        ...,
#        [-0.88760238, -0.52781527,  0.36523384, ..., -1.07045106,
#          0.3382222 , -0.3655201 ],
#        [ 1.34805602, -0.52781527,  0.97373185, ...,  0.81926349,
#          0.35898512, -0.27496629],
#        [ 1.82773455, -0.52781527,  0.97373185, ...,  0.81926349,
#         -0.52623385,  1.93152805]])

# %%
y_train.shape,x_train.shape
# Out:
# ((278,), (278, 13))

# %%
lr = LinearRegression()
fit = lr.fit(x_train,y_train)
pred = lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print(mean_absolute_error(y_test,pred))
print(mean_squared_error(y_test,pred))
print(np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 17.556262069540463
# 348.97504753694307
# 18.680873842969525

# %%
sns.regplot(y_test , pred)
# Out:
# <AxesSubplot:xlabel='target'>

# %%
# Residuals

Residuals = y_test - pred

# %%
sns.distplot(Residuals)
# Out:
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %%
print(lr.coef_)
# Out:
# [ 1.14371626e+00  1.53924081e-01  4.88977929e-01 -1.55431223e-15
#  -2.32949145e+00  2.88540984e+00  1.41770598e-01 -2.32406037e+00
#   1.16467457e+00 -1.83828654e+00 -2.20788182e+00  1.49221597e-01
#  -3.98775185e+00]

# %%
lr.intercept_
# Out:
# 22.425539568345325

# %%
lr.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}
